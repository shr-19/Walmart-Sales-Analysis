# %%
##Importing the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
##Reading the data

# %%
df=pd.read_csv("E:/walmart/Walmart.csv")
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   object
#  2   Ship Date      3203 non-null   object
#  3   Customer Name  3203 non-null   object
#  4   Country        3203 non-null   object
#  5   City           3203 non-null   object
#  6   State          3203 non-null   object
#  7   Category       3203 non-null   object
#  8   Product Name   3203 non-null   object
#  9   Sales          3203 non-null   float64
#  10  Quantity       3203 non-null   int64
#  11  Profit         3203 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 300.4+ KB

# %%
##Analyzing and Visualization the Data

# %%
Country_sales=df.Sales.mean()
Country_profit=df.Profit.mean()
Country_sales,Country_profit
# Out:
# (226.4932656884171, 33.849138307836405)

# %%
Country_pie=pd.DataFrame({'Attributes':["Country_sales","Country_profit"],
                        'Mean':[226.4932656884171,33.849138307836405]})
Country_pie.set_index('Attributes', inplace=True)
pl = Country_pie.plot.pie(subplots=True, title="Walmart Sales Analysis in United States", legend=False,
                   autopct='%1.1f%%', startangle=0,figsize=(5,5))

# %%
df.City.value_counts()
# Out:
# Los_Angeles       747
# San_Francisco     510
# Seattle           428
# San_Diego         170
# Phoenix            63
#                  ...
# Cheyenne            1
# Yucaipa             1
# Redding             1
# Citrus Heights      1
# Layton              1
# Name: City, Length: 169, dtype: int64

# %%
df.Country.value_counts()
# Out:
# United States    3203
# Name: Country, dtype: int64

# %%
df.State.value_counts()
# Out:
# California    2001
# Washington     506
# Arizona        224
# Colorado       182
# Oregon         124
# Utah            53
# Nevada          39
# New Mexico      37
# Idaho           21
# Montana         15
# Wyoming          1
# Name: State, dtype: int64

# %%
c=df.pivot_table(index="City",values=["Sales","Profit"])
c
# Out:
#                   Profit       Sales
# City
# Albuquerque    45.292143  158.583571
# Anaheim        45.702963  295.810370
# Antioch         9.330000   19.440000
# Apple Valley   40.517143  273.584286
# Arvada         14.962500  125.850000
# ...                  ...         ...
# Westminster    44.923529  225.097059
# Whittier       44.480000  444.770000
# Woodland       11.130000   88.220000
# Yucaipa        13.210000   50.800000
# Yuma         -116.497500  210.220000
#
# [169 rows x 2 columns]

# %%
c=c.sort_values(by=["Profit","Sales"],ascending=False)
c
# Out:
#                  Profit        Sales
# City
# Burbank      254.843333  1082.386667
# Lehi         225.835000   758.365000
# Bellingham   203.533333  1263.413333
# Great Falls  197.837500   575.697500
# Des Moines   178.620000   493.491429
# ...                 ...          ...
# Ontario      -46.140000   283.920000
# Littleton    -98.800000    72.290000
# Pueblo      -112.622500   210.867500
# Yuma        -116.497500   210.220000
# Louisville  -141.924167   211.267083
#
# [169 rows x 2 columns]

# %%
top=c.head(10)
top
# Out:
#                       Profit        Sales
# City
# Burbank           254.843333  1082.386667
# Lehi              225.835000   758.365000
# Bellingham        203.533333  1263.413333
# Great Falls       197.837500   575.697500
# Des Moines        178.620000   493.491429
# Sacramento        159.206923   562.404615
# Missoula          152.500000   487.980000
# Huntington Beach  146.673333   421.303333
# North Las Vegas   140.480000   612.562500
# Torrance          136.290000   783.067500

# %%
topp=c.nlargest(10,"Sales")
topp.plot(kind="bar",title="City-Wise Sales and Profit")
# Out:
# <Axes: title={'center': 'City-Wise Sales and Profit'}, xlabel='City'>

# %%
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Customer Name    0
# Country          0
# City             0
# State            0
# Category         0
# Product Name     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %%
col=pd.DataFrame(df,columns=["Category","Product Name"])
col
# Out:
#          Category                                       Product Name
# 0          Labels  Self-Adhesive Address Labels for Typewriters b...
# 1     Furnishings  Eldon Expressions Wood and Plastic Desk Access...
# 2             Art                                         Newell 322
# 3          Phones                     Mitel 5320 IP Phone VoIP phone
# 4         Binders  DXL Angle-View Binders with Locking Rings by S...
# ...           ...                                                ...
# 3198  Accessories  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...
# 3199  Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...
# 3200       Phones                              Aastra 57i VoIP phone
# 3201        Paper  It's Hot Message Books with Stickers, 2 3/4" x 5"
# 3202   Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...
#
# [3203 rows x 2 columns]

# %%
df.Category.value_counts()
# Out:
# Binders        471
# Paper          450
# Furnishings    304
# Phones         277
# Storage        266
# Accessories    258
# Art            250
# Chairs         207
# Appliances     136
# Labels         116
# Tables         116
# Bookcases       80
# Fasteners       72
# Supplies        69
# Envelopes       67
# Machines        39
# Copiers         25
# Name: Category, dtype: int64

# %%
df.rename(columns={"Product Name":"Product"},inplace=True)
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
df.Product.value_counts()
# Out:
# Staples                                                 60
# Avery Non-Stick Binders                                  8
# Bretford Rectangular Conference Table Tops               7
# Global Troy Executive Leather Low-Back Tilter            7
# SAFCO Arco Folding Chair                                 7
#                                                         ..
# Avery 505                                                1
# RCA ViSYS 25423RE1 Corded phone                          1
# Master Giant Foot Doorstop, Safety Yellow                1
# Bush Westfield Collection Bookcases, Fully Assembled     1
# Avaya 5410 Digital phone                                 1
# Name: Product, Length: 1494, dtype: int64

# %%
dataframe = pd.DataFrame(df, columns = ["City","Product"])
rslt_df = dataframe[dataframe['Product'] == "Staples"]
rslt_df
# Out:
#                City  Product
# 57         Carlsbad  Staples
# 81         Portland  Staples
# 215    Sierra_Vista  Staples
# 268   San_Francisco  Staples
# 352     Los_Angeles  Staples
# 532       San_Diego  Staples
# 569     Los_Angeles  Staples
# 609       Brentwood  Staples
# 631     Los_Angeles  Staples
# 740     Los_Angeles  Staples
# 752          Fresno  Staples
# 756       San_Diego  Staples
# 763   San_Francisco  Staples
# 766     Los_Angeles  Staples
# 800   San_Francisco  Staples
# 866      Las_Cruces  Staples
# 908   San_Francisco  Staples
# 910   San_Francisco  Staples
# 1017  San_Francisco  Staples
# 1039          Tempe  Staples
# 1254        Seattle  Staples
# 1327    Los_Angeles  Staples
# 1352    Los_Angeles  Staples
# 1377  San_Francisco  Staples
# 1381    Los_Angeles  Staples
# 1384  San_Francisco  Staples
# 1428     Louisville  Staples
# 1485          Logan  Staples
# 1502        Seattle  Staples
# 1567        Seattle  Staples
# 1577         Aurora  Staples
# ...

# %%
rslt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 57 to 3162
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     60 non-null     object
#  1   Product  60 non-null     object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
pro=rslt_df.value_counts()
pro
# Out:
# City           Product
# Los_Angeles    Staples    16
# San_Francisco  Staples    12
# Seattle        Staples     6
# San_Diego      Staples     3
# Brentwood      Staples     3
# Moreno_Valley  Staples     2
# Aurora         Staples     1
# Mission_Viejo  Staples     1
# Tempe          Staples     1
# Sierra_Vista   Staples     1
# Scottsdale     Staples     1
# San_Jose       Staples     1
# Portland       Staples     1
# Louisville     Staples     1
# Longview       Staples     1
# Long_Beach     Staples     1
# Logan          Staples     1
# Las_Cruces     Staples     1
# Greeley        Staples     1
# Fresno         Staples     1
# Costa_Mesa     Staples     1
# Chico          Staples     1
# Carlsbad       Staples     1
# Thornton       Staples     1
# dtype: int64

# %%
pro.plot(kind="bar",title="Highest Product Count")
# Out:
# <Axes: title={'center': 'Highest Product Count'}, xlabel='City,Product'>

# %%
dataf=pd.DataFrame(df,columns=["City","Product","Sales"])
staple_sale=dataf[dataframe['Product'] == "Staples"]
staple_sale.sort_values(by="Sales",ascending=False)
# Out:
#                City  Product   Sales
# 81         Portland  Staples  141.76
# 1889      San_Diego  Staples  105.52
# 2423    Los_Angeles  Staples   87.84
# 908   San_Francisco  Staples   83.79
# 800   San_Francisco  Staples   77.92
# 2442  San_Francisco  Staples   71.88
# 1567        Seattle  Staples   61.96
# 1606    Los_Angeles  Staples   56.70
# 3054        Seattle  Staples   52.76
# 2418    Los_Angeles  Staples   52.76
# 866      Las_Cruces  Staples   49.12
# 1922  San_Francisco  Staples   45.36
# 1377  San_Francisco  Staples   43.92
# 1327    Los_Angeles  Staples   43.92
# 2347       San_Jose  Staples   39.76
# 910   San_Francisco  Staples   31.92
# 215    Sierra_Vista  Staples   31.56
# 1724        Seattle  Staples   31.44
# 1384  San_Francisco  Staples   30.40
# 1994     Costa_Mesa  Staples   29.22
# 57         Carlsbad  Staples   28.40
# 2606    Los_Angeles  Staples   25.76
# 763   San_Francisco  Staples   24.20
# 609       Brentwood  Staples   23.88
# ...

# %%
top_s=staple_sale.value_counts()
top_s
# Out:
# City           Product  Sales
# San_Francisco  Staples  7.36      2
# Aurora         Staples  4.51      1
# San_Francisco  Staples  45.36     1
# Moreno_Valley  Staples  10.98     1
# Portland       Staples  141.76    1
# San_Diego      Staples  7.86      1
#                         12.35     1
#                         105.52    1
# San_Francisco  Staples  9.78      1
#                         15.56     1
#                         24.20     1
#                         30.40     1
#                         31.92     1
#                         43.92     1
#                         71.88     1
# Mission_Viejo  Staples  8.67      1
# San_Francisco  Staples  77.92     1
#                         83.79     1
# San_Jose       Staples  39.76     1
# Scottsdale     Staples  23.47     1
# Seattle        Staples  7.58      1
#                         8.94      1
#                         23.88     1
#                         31.44     1
#                         52.76     1
# ...

# %%
brentwood=staple_sale.loc[df.City=="Brentwood"].mean()
brentwood
# Out:
# C:\Users\Shruti Jain\AppData\Local\Temp\ipykernel_248\2865705625.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brentwood=staple_sale.loc[df.City=="Brentwood"].mean()
# Sales    19.306667
# dtype: float64

# %%
df=pd.read_csv("E:/walmart/Walmart.csv")
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
San_Francisco=staple_sale.loc[df.City=="San_Francisco"].mean()
San_Francisco
# Out:
# C:\Users\Shruti Jain\AppData\Local\Temp\ipykernel_248\4049191277.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   San_Francisco=staple_sale.loc[df.City=="San_Francisco"].mean()
# Sales    37.454167
# dtype: float64

# %%
Los_Angeles=staple_sale.loc[df.City=="Los_Angeles"].mean()
Los_Angeles
# Out:
# C:\Users\Shruti Jain\AppData\Local\Temp\ipykernel_248\2934956584.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Los_Angeles=staple_sale.loc[df.City=="Los_Angeles"].mean()
# Sales    25.3
# dtype: float64

# %%
San_Diego=staple_sale.loc[df.City=="San_Diego"].mean()
San_Diego
# Out:
# C:\Users\Shruti Jain\AppData\Local\Temp\ipykernel_248\3408864870.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   San_Diego=staple_sale.loc[df.City=="San_Diego"].mean()
# Sales    41.91
# dtype: float64

# %%
Seattle=staple_sale.loc[df.City=="Seattle"].mean()
Seattle
# Out:
# C:\Users\Shruti Jain\AppData\Local\Temp\ipykernel_248\1983384103.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Seattle=staple_sale.loc[df.City=="Seattle"].mean()
# Sales    31.093333
# dtype: float64

# %%
Portland=staple_sale.loc[df.City=="Portland"].mean()
Portland
# Out:
# C:\Users\Shruti Jain\AppData\Local\Temp\ipykernel_248\2660603058.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Portland=staple_sale.loc[df.City=="Portland"].mean()
# Sales    141.76
# dtype: float64

# %%
Sales_pie=pd.DataFrame({'City':["Portland","Seattle","San_Diego","Los_Angeles","San_Francisco","brentwood"],
                        'Mean_Sale':[141.76,31.093333,41.91,25.3,37.454167,19.306667]})
Sales_pie.set_index('City', inplace=True)
plot = Sales_pie.plot.pie(subplots=True, title="Percentage of Sales with Staple Product", legend=False,
                   autopct='%1.1f%%', startangle=0,figsize=(13,8))

# %%
df.State.value_counts()
# Out:
# California    2001
# Washington     506
# Arizona        224
# Colorado       182
# Oregon         124
# Utah            53
# Nevada          39
# New Mexico      37
# Idaho           21
# Montana         15
# Wyoming          1
# Name: State, dtype: int64

# %%
s=df.pivot_table(index="State",values=["Sales","Profit"])
s.sort_values(by=["Sales","Profit"],ascending=False)
# Out:
#                 Profit        Sales
# State
# Wyoming     100.200000  1603.140000
# Nevada       85.045128   428.951282
# Montana     122.221333   372.623333
# Washington   66.013241   273.994644
# California   38.171714   228.729475
# Utah         48.048302   211.699245
# Idaho        39.368095   208.690000
# Colorado    -35.867363   176.418242
# Arizona     -15.302991   157.509018
# Oregon       -9.600645   140.573710
# New Mexico   31.273784   129.284865

# %%
ss=s.nlargest(11,'Sales')
ss.plot(kind="bar",title="State-Wise Sales and Profit")
# Out:
# <Axes: title={'center': 'State-Wise Sales and Profit'}, xlabel='State'>
